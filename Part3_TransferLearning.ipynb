# %%
#from keras.utils import normalize
import os
import glob
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from collections import Counter

# %%
#Resizing images, if needed
SIZE_X = 224 
SIZE_Y = 224
n_classes=4 #Number of classes for segmentation
num_images = 12 #Total 1600 available but we can use a subset for speedy training

# %% [markdown]
# # Defining the metrics :
# # IoU / Dice coefficient / Pixel accuracy

# %%
# metrics

 

import numpy as np

import pandas as pd

 

def calculate_iou(true_mask, pred_mask):

    intersection = np.logical_and(true_mask, pred_mask)

    union = np.logical_or(true_mask, pred_mask)

    iou_score = np.sum(intersection) / np.sum(union)

    return iou_score

 

def calculate_dice_coefficient(true_mask, pred_mask):

    intersection = np.logical_and(true_mask, pred_mask)

    dice_coefficient = (2.0 * np.sum(intersection)) / (np.sum(true_mask) + np.sum(pred_mask))

    return dice_coefficient

 

def calculate_pixel_accuracy(true_mask, pred_mask):

    correct_pixels = np.sum(true_mask == pred_mask)

    total_pixels = true_mask.size

    pixel_accuracy = correct_pixels / total_pixels

    return pixel_accuracy



def calculate_segmentation_metrics(true_mask, pred_mask):

    iou_score = calculate_iou(true_mask, pred_mask)

    dice_coefficient = calculate_dice_coefficient(true_mask, pred_mask)

    pixel_accuracy = calculate_pixel_accuracy(true_mask, pred_mask)

 

    metrics_table = pd.DataFrame({

        'Metrics': ['IoU', 'Dice Coefficient', 'Pixel Accuracy'],

        'Score': [iou_score, dice_coefficient, pixel_accuracy]

    })

 

    return metrics_table

# %% [markdown]
# # Data importation

# %% [markdown]
# ## Breast Cancer Data

# %%
import cv2
import numpy as np

path = "train_test_full_roi-20230406T080206Z-001/train_test_full_roi/Dataset_BUSI_with_GT/benign"
images_names1 = [path + '/benign ({}).png'.format(k) for k in range(1, 438)]
# images_names2 = [path + '/malignant ({}).png'.format(k) for k in range(1, 211)]
# images_names3 = [path + '/normal ({}).png'.format(k) for k in range(1, 134)]

images_names = images_names1

images_names.sort()
images_names_subset = images_names

X_train1 = []

for mask in images_names_subset:
    img = cv2.imread(mask,0)
  
    # Trouver les indices des pixels qui ont une valeur différente de 255
    indices = np.where(img != 255)

    # Calculer les limites de la zone qui contient les pixels non nuls
    y_min, x_min = np.min(indices, axis=1)
    y_max, x_max = np.max(indices, axis=1)

    # Extraire la zone qui contient les pixels non nuls de l'image
    img = img[y_min:y_max + 1, x_min:x_max + 1]
  
    # Redimensionner l'image à une taille fixe de 224x224
    img = cv2.resize(img, (224, 224))
  
    X_train1.append(img)

X_train1 = np.array(X_train1)
X_train1 = np.expand_dims(X_train1, axis=-1)
X_train1 = np.repeat(X_train1, 3, axis=-1)

# %%
import cv2
import numpy as np

path = "train_test_full_roi-20230406T080206Z-001/train_test_full_roi/Dataset_BUSI_with_GT/malignant"
# images_names1 = [path + '/benign ({}).png'.format(k) for k in range(1, 438)]
images_names2 = [path + '/malignant ({}).png'.format(k) for k in range(1, 211)]
# images_names3 = [path + '/normal ({}).png'.format(k) for k in range(1, 134)]

images_names = images_names2

images_names.sort()
images_names_subset = images_names

X_train2 = []

for mask in images_names_subset:
    img = cv2.imread(mask,0)
  
    # Trouver les indices des pixels qui ont une valeur différente de 255
    indices = np.where(img != 255)

    # Calculer les limites de la zone qui contient les pixels non nuls
    y_min, x_min = np.min(indices, axis=1)
    y_max, x_max = np.max(indices, axis=1)

    # Extraire la zone qui contient les pixels non nuls de l'image
    img = img[y_min:y_max + 1, x_min:x_max + 1]
  
    # Redimensionner l'image à une taille fixe de 224x224
    img = cv2.resize(img, (224, 224))
  
    X_train2.append(img)

X_train2 = np.array(X_train2)
X_train2 = np.expand_dims(X_train2, axis=-1)
X_train2 = np.repeat(X_train2, 3, axis=-1)

# %%
X_train2.shape
# Out:
# (210, 224, 224, 3)

# %%
import cv2
import numpy as np

path = "train_test_full_roi-20230406T080206Z-001/train_test_full_roi/Dataset_BUSI_with_GT/benign"
mask_names1 = [path + '/benign ({})_mask.png'.format(k) for k in range(1, 438)]
# mask_names2 = [path + '/malignant ({})_mask.png'.format(k) for k in range(1, 211)]
# mask_names3 = [path + '/normal ({})_mask.png'.format(k) for k in range(1, 134)]

mask_names = mask_names1

mask_names.sort()
mask_names_subset = mask_names

y_train1 = []

for mask in mask_names_subset:
    img = cv2.imread(mask, 0)
    # Trouver les indices des pixels qui ont une valeur différente de 255
    indices = np.where(img != 255)

    

    # Calculer les limites de la zone qui contient les pixels non nuls
    y_min, x_min = np.min(indices, axis=1)
    y_max, x_max = np.max(indices, axis=1)

    # Extraire la zone qui contient les pixels non nuls de l'image
    img = img[y_min:y_max + 1, x_min:x_max + 1]
  
    # Redimensionner l'image à une taille fixe de 224x224
    img = cv2.resize(img, (224, 224))
  
    y_train1.append(img)

y_train1 = np.array(y_train1)

# %%
import cv2
import numpy as np
path = "train_test_full_roi-20230406T080206Z-001/train_test_full_roi/Dataset_BUSI_with_GT/malignant"
# mask_names1 = [path + '/malignant ({})_mask.png'.format(k) for k in range(1, 438)]
mask_names2 = [path + '/malignant ({})_mask.png'.format(k) for k in range(1, 211)]
# mask_names3 = [path + '/normal ({})_mask.png'.format(k) for k in range(1, 134)]

mask_names = mask_names2

mask_names.sort()
mask_names_subset = mask_names

y_train2 = []

for mask in mask_names_subset:
    img = cv2.imread(mask, 0)
  
    # Trouver les indices des pixels qui ont une valeur différente de 255
    indices = np.where(img != 255)

    # Calculer les limites de la zone qui contient les pixels non nuls
    y_min, x_min = np.min(indices, axis=1)
    y_max, x_max = np.max(indices, axis=1)

    # Extraire la zone qui contient les pixels non nuls de l'image
    img = img[y_min:y_max + 1, x_min:x_max + 1]
  
    # Redimensionner l'image à une taille fixe de 224x224
    img = cv2.resize(img, (224, 224))
  
    y_train2.append(img)

y_train2 = np.array(y_train2)

# %%
y_train2.shape
# Out:
# (210, 224, 224)

# %% [markdown]
# # Nerf optic data

# %%
path= "train_test_full_roi-20230406T080206Z-001/train_test_full_roi/train_data/img_224"
image_names = [path+'/img{}.png'.format(k) for k in range(1,13)]

image_names.sort()
image_names_subset = image_names[0:num_images]
images = [cv2.imread(image, 1) for image in image_names_subset] #SM backbones use 3 channel images, so let us read images in color.
X_train = np.array(images)
X_train = X_train

# %%
X_train.shape
# Out:
# (12, 224, 224, 3)

# %%
#we should replace the masks !

path = "train_test_full_roi-20230406T080206Z-001/train_test_full_roi/train_data/msk3c_224"
mask_names = [path+'/img{}_mask1.png'.format(k) for k in range(1,13)]
mask_names.sort()
mask_names_subset = mask_names[0:num_images]
masks = [cv2.imread(mask, 0) for mask in mask_names_subset]
mask1_dataset_train_ = np.array(masks)

# %%
#we should replace the masks !

path = "train_test_full_roi-20230406T080206Z-001/train_test_full_roi/train_data/msk3c_224"
mask_names = [path+'/img{}_mask2.png'.format(k) for k in range(1,13)]
mask_names.sort()
mask_names_subset = mask_names[0:num_images]
masks = [cv2.imread(mask, 0) for mask in mask_names_subset]
mask2_dataset_train_ = np.array(masks)

# %%
#we should replace the masks !

path = "train_test_full_roi-20230406T080206Z-001/train_test_full_roi/train_data/msk3c_224"
mask_names = [path+'/img{}_mask3.png'.format(k) for k in range(1,13)]
mask_names.sort()
mask_names_subset = mask_names[0:num_images]
masks = [cv2.imread(mask, 0) for mask in mask_names_subset]
mask3_dataset_train_ = np.array(masks)

# %%
proccesed_images = []

for i in range(12):
    img = mask1_dataset_train_[i,:,:]
  
    # Trouver les indices des pixels qui ont une valeur différente de 255
    indices = np.where(img != 255)

    # Calculer les limites de la zone qui contient les pixels non nuls
    y_min, x_min = np.min(indices, axis=1)
    y_max, x_max = np.max(indices, axis=1)

    # Extraire la zone qui contient les pixels non nuls de l'image
    img = img[y_min:y_max+1, x_min:x_max+1]
    img = cv2.resize(img, (224, 224))
    proccesed_images.append(img)

mask1_dataset_train_=np.array(proccesed_images)

# %%
proccesed_images = []

for i in range(12):
    img = mask2_dataset_train_[i,:,:]
  
    # Trouver les indices des pixels qui ont une valeur différente de 255
    indices = np.where(img != 255)

    # Calculer les limites de la zone qui contient les pixels non nuls
    y_min, x_min = np.min(indices, axis=1)
    y_max, x_max = np.max(indices, axis=1)

    # Extraire la zone qui contient les pixels non nuls de l'image
    img = img[y_min:y_max+1, x_min:x_max+1]
    img = cv2.resize(img, (224, 224))
    proccesed_images.append(img)

mask2_dataset_train_=np.array(proccesed_images)

# %%
proccesed_images = []

for i in range(12):
    img = mask3_dataset_train_[i,:,:]
  
    # Trouver les indices des pixels qui ont une valeur différente de 255
    indices = np.where(img != 255)

    # Calculer les limites de la zone qui contient les pixels non nuls
    y_min, x_min = np.min(indices, axis=1)
    y_max, x_max = np.max(indices, axis=1)

    # Extraire la zone qui contient les pixels non nuls de l'image
    img = img[y_min:y_max+1, x_min:x_max+1]
    img = cv2.resize(img, (224, 224))
    proccesed_images.append(img)

mask3_dataset_train_=np.array(proccesed_images)

# %%
path = "train_test_full_roi-20230406T080206Z-001/train_test_full_roi/test_data\img_224"
image_names = [path+'/img{}.png'.format(k) for k in range(13,16)]

image_names.sort()
image_names_subset = image_names[0:num_images]
images = [cv2.imread(image, 1) for image in image_names_subset] #SM backbones use 3 channel images, so let us read images in color.
X_test = np.array(images)
X_test = X_test

# %%
X_test.shape
# Out:
# (3, 224, 224, 3)

# %%
path = "train_test_full_roi-20230406T080206Z-001/train_test_full_roi/test_data\msk3c_224"
mask_names = [path+'/img{}_mask1.png'.format(k) for k in range(13,16)]
mask_names.sort()
mask_names_subset = mask_names[0:num_images]
masks = [cv2.imread(mask, 0) for mask in mask_names_subset]
mask1_dataset_test = np.array(masks)

# %%
path = "train_test_full_roi-20230406T080206Z-001/train_test_full_roi/test_data\msk3c_224"
mask_names = [path+'/img{}_mask2.png'.format(k) for k in range(13,16)]
mask_names.sort()
mask_names_subset = mask_names[0:num_images]
masks = [cv2.imread(mask, 0) for mask in mask_names_subset]
mask2_dataset_test = np.array(masks)

# %%
path = "train_test_full_roi-20230406T080206Z-001/train_test_full_roi/test_data\msk3c_224"
mask_names = [path+'/img{}_mask3.png'.format(k) for k in range(13,16)]
mask_names.sort()
mask_names_subset = mask_names[0:num_images]
masks = [cv2.imread(mask, 0) for mask in mask_names_subset]
mask3_dataset_test = np.array(masks)

# %%
mask3_dataset_test.shape
# Out:
# (3, 224, 224)

# %% [markdown]
# # Data processing

# %% [markdown]
# # Standardizing the data size

# %%
proccesed_images = []

for i in range(3):
    img = mask1_dataset_test[i,:,:]
  
    # Trouver les indices des pixels qui ont une valeur différente de 255
    indices = np.where(img != 255)

    # Calculer les limites de la zone qui contient les pixels non nuls
    y_min, x_min = np.min(indices, axis=1)
    y_max, x_max = np.max(indices, axis=1)

    # Extraire la zone qui contient les pixels non nuls de l'image
    img = img[y_min:y_max+1, x_min:x_max+1]
    img = cv2.resize(img, (224, 224))
    proccesed_images.append(img)
  
mask1_dataset_test=np.array(proccesed_images)

# %%
proccesed_images = []

for i in range(3):
    img = mask2_dataset_test[i,:,:]
  
    # Trouver les indices des pixels qui ont une valeur différente de 255
    indices = np.where(img != 255)

    # Calculer les limites de la zone qui contient les pixels non nuls
    y_min, x_min = np.min(indices, axis=1)
    y_max, x_max = np.max(indices, axis=1)

    # Extraire la zone qui contient les pixels non nuls de l'image
    img = img[y_min:y_max+1, x_min:x_max+1]
    img = cv2.resize(img, (224, 224))
    proccesed_images.append(img)
  
mask2_dataset_test=np.array(proccesed_images)

# %%
proccesed_images = []

for i in range(3):
    img = mask3_dataset_test[i,:,:]
  
    # Trouver les indices des pixels qui ont une valeur différente de 255
    indices = np.where(img != 255)

    # Calculer les limites de la zone qui contient les pixels non nuls
    y_min, x_min = np.min(indices, axis=1)
    y_max, x_max = np.max(indices, axis=1)

    # Extraire la zone qui contient les pixels non nuls de l'image
    img = img[y_min:y_max+1, x_min:x_max+1]
    img = cv2.resize(img, (224, 224))
    proccesed_images.append(img)
  
mask3_dataset_test=np.array(proccesed_images)

# %% [markdown]
# # Encoding labels(masks)

# %%
#Encode labels to 0, 1, 2, 3, ... but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = mask2_dataset_train_.shape  
mask2_dataset_reshaped = mask2_dataset_train_.reshape(-1,1)
mask2_dataset_reshaped_encoded = labelencoder.fit_transform(mask2_dataset_reshaped)
y_train_mask2 = mask2_dataset_reshaped_encoded.reshape(n, h, w)

n, h, w = mask2_dataset_test.shape  
mask2_dataset_reshaped = mask2_dataset_test.reshape(-1,1)
mask2_dataset_reshaped_encoded = labelencoder.fit_transform(mask2_dataset_reshaped)
y_test_mask2 = mask2_dataset_reshaped_encoded.reshape(n, h, w)
# Out:
# c:\Users\Mrabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Mrabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#Encode labels to 0, 1, 2, 3, ... but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = mask1_dataset_train_.shape  
mask1_dataset_reshaped = mask1_dataset_train_.reshape(-1,1)
mask1_dataset_reshaped_encoded = labelencoder.fit_transform(mask1_dataset_reshaped)
y_train_mask1 = mask1_dataset_reshaped_encoded.reshape(n, h, w)

n, h, w = mask1_dataset_test.shape  
mask1_dataset_reshaped = mask1_dataset_test.reshape(-1,1)
mask1_dataset_reshaped_encoded = labelencoder.fit_transform(mask1_dataset_reshaped)
y_test_mask1 = mask1_dataset_reshaped_encoded.reshape(n, h, w)
# Out:
# c:\Users\Mrabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Mrabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#Encode labels to 0, 1, 2, 3, ... but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = mask3_dataset_train_.shape  
mask3_dataset_reshaped = mask3_dataset_train_.reshape(-1,1)
mask3_dataset_reshaped_encoded = labelencoder.fit_transform(mask3_dataset_reshaped)
y_train_mask3 = mask3_dataset_reshaped_encoded.reshape(n, h, w)

n, h, w = mask3_dataset_test.shape  
mask3_dataset_reshaped = mask3_dataset_test.reshape(-1,1)
mask3_dataset_reshaped_encoded = labelencoder.fit_transform(mask3_dataset_reshaped)
y_test_mask3 = mask3_dataset_reshaped_encoded.reshape(n, h, w)
# Out:
# c:\Users\Mrabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Mrabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Final training data for the first UNet model(trained on the large data)

# %%
X_train_total = np.concatenate((X_train, X_train1, X_train2), axis=0)
y_train_mask1_total = np.concatenate((y_train_mask1, y_train1, y_train2),axis=0)
y_train_mask2_total = np.concatenate((y_train_mask2, y_train1, y_train2),axis=0)
y_train_mask3_total = np.concatenate((y_train_mask3, y_train1, y_train2),axis=0)

# %% [markdown]
# # Building the UNet Architecure

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, 2, strides=2, padding="same")(inputs) # up conv
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet0(input_shape): # 3 encoder blocks and 3 decoder blocks
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 32)
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)

    b1 = conv_block(p3, 256)

    d1 = decoder_block(b1, s3, 128)
    d2 = decoder_block(d1, s2, 64)
    d3 = decoder_block(d2, s1, 32)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d3)

    model = Model(inputs, outputs, name="UNET")
    return model
    
def build_unet1(input_shape): # 4 encoder blocks and 4 decoder blocks
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 32)
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256)

    b1 = conv_block(p4, 512)

    d1 = decoder_block(b1, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model


def build_unet2(input_shape): # 5 encoder blocks and 5 decoder blocks
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 32)
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256)
    s5, p5 = encoder_block(p4, 512)

    b1 = conv_block(p5, 1024)
    
    d1 = decoder_block(b1, s5, 512)
    d2 = decoder_block(d1, s4, 256)
    d3 = decoder_block(d2, s3, 128)
    d4 = decoder_block(d3, s2, 64)
    d5 = decoder_block(d4, s1, 32)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d5)

    model = Model(inputs, outputs, name="UNET")
    return model

if __name__ == "__main__":
    input_shape = (224, 224, 3)
    model = build_unet2(input_shape)
    model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_92 (Conv2D)             (None, 224, 224, 32  896         ['input_5[0][0]']
#                                 )
#
#  batch_normalization_88 (BatchN  (None, 224, 224, 32  128        ['conv2d_92[0][0]']
#  ormalization)                  )
#
#  activation_88 (Activation)     (None, 224, 224, 32  0           ['batch_normalization_88[0][0]']
#                                 )
#
#  conv2d_93 (Conv2D)             (None, 224, 224, 32  9248        ['activation_88[0][0]']
#                                 )
#
#  batch_normalization_89 (BatchN  (None, 224, 224, 32  128        ['conv2d_93[0][0]']
#  ormalization)                  )
#
#  activation_89 (Activation)     (None, 224, 224, 32  0           ['batch_normalization_89[0][0]']
#                                 )
#
#  max_pooling2d_20 (MaxPooling2D  (None, 112, 112, 32  0          ['activation_89[0][0]']
#  )                              )
#
#  conv2d_94 (Conv2D)             (None, 112, 112, 64  18496       ['max_pooling2d_20[0][0]']
#                                 )
#
#  batch_normalization_90 (BatchN  (None, 112, 112, 64  256        ['conv2d_94[0][0]']
#  ormalization)                  )
#
#  activation_90 (Activation)     (None, 112, 112, 64  0           ['batch_normalization_90[0][0]']
#                                 )
#
#  conv2d_95 (Conv2D)             (None, 112, 112, 64  36928       ['activation_90[0][0]']
#                                 )
#
#  batch_normalization_91 (BatchN  (None, 112, 112, 64  256        ['conv2d_95[0][0]']
#  ormalization)                  )
#
#  activation_91 (Activation)     (None, 112, 112, 64  0           ['batch_normalization_91[0][0]']
#                                 )
#
#  max_pooling2d_21 (MaxPooling2D  (None, 56, 56, 64)  0           ['activation_91[0][0]']
#  )
#
#  conv2d_96 (Conv2D)             (None, 56, 56, 128)  73856       ['max_pooling2d_21[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 56, 56, 128)  512        ['conv2d_96[0][0]']
#  ormalization)
#
#  activation_92 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_92[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 56, 56, 128)  147584      ['activation_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 56, 56, 128)  512        ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_93 (Activation)     (None, 56, 56, 128)  0           ['batch_normalization_93[0][0]']
#
#  max_pooling2d_22 (MaxPooling2D  (None, 28, 28, 128)  0          ['activation_93[0][0]']
#  )
#
#  conv2d_98 (Conv2D)             (None, 28, 28, 256)  295168      ['max_pooling2d_22[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_98[0][0]']
#  ormalization)
#
#  activation_94 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_94[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 28, 28, 256)  590080      ['activation_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 28, 28, 256)  1024       ['conv2d_99[0][0]']
#  ormalization)
#
#  activation_95 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_95[0][0]']
#
#  max_pooling2d_23 (MaxPooling2D  (None, 14, 14, 256)  0          ['activation_95[0][0]']
#  )
#
#  conv2d_100 (Conv2D)            (None, 14, 14, 512)  1180160     ['max_pooling2d_23[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_100[0][0]']
#  ormalization)
#
#  activation_96 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_96[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 14, 14, 512)  2359808     ['activation_96[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 14, 14, 512)  2048       ['conv2d_101[0][0]']
#  ormalization)
#
#  activation_97 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_97[0][0]']
#
#  max_pooling2d_24 (MaxPooling2D  (None, 7, 7, 512)   0           ['activation_97[0][0]']
#  )
#
#  conv2d_102 (Conv2D)            (None, 7, 7, 1024)   4719616     ['max_pooling2d_24[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_102[0][0]']
#  ormalization)
#
#  activation_98 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_98[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 7, 7, 1024)   9438208     ['activation_98[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_103[0][0]']
#  ormalization)
#
#  activation_99 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_99[0][0]']
#
#  conv2d_transpose_20 (Conv2DTra  (None, 14, 14, 512)  2097664    ['activation_99[0][0]']
#  nspose)
#
#  concatenate_20 (Concatenate)   (None, 14, 14, 1024  0           ['conv2d_transpose_20[0][0]',
#                                 )                                 'activation_97[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 14, 14, 512)  4719104     ['concatenate_20[0][0]']
#
#  batch_normalization_100 (Batch  (None, 14, 14, 512)  2048       ['conv2d_104[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 14, 14, 512)  0           ['batch_normalization_100[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 14, 14, 512)  2359808     ['activation_100[0][0]']
#
#  batch_normalization_101 (Batch  (None, 14, 14, 512)  2048       ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_101 (Activation)    (None, 14, 14, 512)  0           ['batch_normalization_101[0][0]']
#
#  conv2d_transpose_21 (Conv2DTra  (None, 28, 28, 256)  524544     ['activation_101[0][0]']
#  nspose)
#
#  concatenate_21 (Concatenate)   (None, 28, 28, 512)  0           ['conv2d_transpose_21[0][0]',
#                                                                   'activation_95[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 28, 28, 256)  1179904     ['concatenate_21[0][0]']
#
#  batch_normalization_102 (Batch  (None, 28, 28, 256)  1024       ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 28, 28, 256)  0           ['batch_normalization_102[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 28, 28, 256)  590080      ['activation_102[0][0]']
#
#  batch_normalization_103 (Batch  (None, 28, 28, 256)  1024       ['conv2d_107[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 28, 28, 256)  0           ['batch_normalization_103[0][0]']
#
#  conv2d_transpose_22 (Conv2DTra  (None, 56, 56, 128)  131200     ['activation_103[0][0]']
#  nspose)
#
#  concatenate_22 (Concatenate)   (None, 56, 56, 256)  0           ['conv2d_transpose_22[0][0]',
#                                                                   'activation_93[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 56, 56, 128)  295040      ['concatenate_22[0][0]']
#
#  batch_normalization_104 (Batch  (None, 56, 56, 128)  512        ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_104 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_104[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 56, 56, 128)  147584      ['activation_104[0][0]']
#
#  batch_normalization_105 (Batch  (None, 56, 56, 128)  512        ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_105[0][0]']
#
#  conv2d_transpose_23 (Conv2DTra  (None, 112, 112, 64  32832      ['activation_105[0][0]']
#  nspose)                        )
#
#  concatenate_23 (Concatenate)   (None, 112, 112, 12  0           ['conv2d_transpose_23[0][0]',
#                                 8)                                'activation_91[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 112, 112, 64  73792       ['concatenate_23[0][0]']
#                                 )
#
#  batch_normalization_106 (Batch  (None, 112, 112, 64  256        ['conv2d_110[0][0]']
#  Normalization)                 )
#
#  activation_106 (Activation)    (None, 112, 112, 64  0           ['batch_normalization_106[0][0]']
#                                 )
#
#  conv2d_111 (Conv2D)            (None, 112, 112, 64  36928       ['activation_106[0][0]']
#                                 )
#
#  batch_normalization_107 (Batch  (None, 112, 112, 64  256        ['conv2d_111[0][0]']
#  Normalization)                 )
#
#  activation_107 (Activation)    (None, 112, 112, 64  0           ['batch_normalization_107[0][0]']
#                                 )
#
#  conv2d_transpose_24 (Conv2DTra  (None, 224, 224, 32  8224       ['activation_107[0][0]']
#  nspose)                        )
#
#  concatenate_24 (Concatenate)   (None, 224, 224, 64  0           ['conv2d_transpose_24[0][0]',
#                                 )                                 'activation_89[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 224, 224, 32  18464       ['concatenate_24[0][0]']
#                                 )
#
#  batch_normalization_108 (Batch  (None, 224, 224, 32  128        ['conv2d_112[0][0]']
#  Normalization)                 )
#
#  activation_108 (Activation)    (None, 224, 224, 32  0           ['batch_normalization_108[0][0]']
#                                 )
#
#  conv2d_113 (Conv2D)            (None, 224, 224, 32  9248        ['activation_108[0][0]']
#                                 )
#
#  batch_normalization_109 (Batch  (None, 224, 224, 32  128        ['conv2d_113[0][0]']
#  Normalization)                 )
#
#  activation_109 (Activation)    (None, 224, 224, 32  0           ['batch_normalization_109[0][0]']
#                                 )
#
#  conv2d_114 (Conv2D)            (None, 224, 224, 1)  33          ['activation_109[0][0]']
#
# ==================================================================================================
# Total params: 31,118,561
# Trainable params: 31,106,529
# Non-trainable params: 12,032
# __________________________________________________________________________________________________

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam


""" Global parameters """
H = 224
W = 224


def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)



def tf_parse(x, y):
    def _parse(x, y):
        x = cv2.resize(x, (W, H))
        x = x 
        x = x.astype(np.float32)
        y = cv2.resize(y, (W, H))
        y = y 
        y = y.astype(np.float32)
        y = np.expand_dims(y, axis=-1)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y


def tf_dataset(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 4
    lr = 1e-4
    num_epochs = 5
    model_path = os.path.join("files", "model.h5")
    csv_path = os.path.join("files", "log.csv")

    """ Dataset """
    train_x, train_y = X_train_total , y_train_mask1_total 
    test_x, test_y = X_test , y_test_mask1 

    print(f"Train: {len(X_train)} - {len(y_train_mask1_total)}")
    print(f"Test : {len(X_test)} - {len(y_test_mask1)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    test_dataset = tf_dataset(train_x, train_y, batch=batch_size)

    """ Model """
    model_mask1_total = build_unet2((H, W, 3)) #  Choose your model
    model_mask1_total.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef])

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False),
    ]

    model_mask1_total.fit(
        train_dataset,
        epochs=num_epochs,
        callbacks=callbacks
    )
# Out:
# Train: 12 - 659
# Test : 3 - 3
# Epoch 1/5
# 165/165 [==============================] - ETA: 0s - loss: -0.7067 - dice_coef: 1.7069WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 314s 2s/step - loss: -0.7067 - dice_coef: 1.7069 - lr: 1.0000e-04
# Epoch 2/5
# 165/165 [==============================] - ETA: 0s - loss: -0.8494 - dice_coef: 1.8494WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 310s 2s/step - loss: -0.8494 - dice_coef: 1.8494 - lr: 1.0000e-04
# Epoch 3/5
# 165/165 [==============================] - ETA: 0s - loss: -0.8796 - dice_coef: 1.8797WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 309s 2s/step - loss: -0.8796 - dice_coef: 1.8797 - lr: 1.0000e-04
# Epoch 4/5
# 165/165 [==============================] - ETA: 0s - loss: -0.8897 - dice_coef: 1.8898WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 312s 2s/step - loss: -0.8897 - dice_coef: 1.8898 - lr: 1.0000e-04
# Epoch 5/5
# 165/165 [==============================] - ETA: 0s - loss: -0.8965 - dice_coef: 1.8965WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 315s 2s/step - loss: -0.8965 - dice_coef: 1.8965 - lr: 1.0000e-04

# %% [markdown]
# # UNet model trained on the breast cancer data :  MASK 1

# %%
# batch = 4 , 10 - 0.47 - 1e-4 mask 1 (Unet1)

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import f1_score, jaccard_score, precision_score, recall_score
from sklearn.model_selection import train_test_split


""" Global parameters """
H = 224
W = 224

""" Creating a directory """
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred * 255

    line = np.ones((H, 10, 3)) * 255

    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)
    return cat_images


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("results")

    """ Load the model """
#     with CustomObjectScope({"dice_coef": dice_coef, "dice_loss": dice_loss}):
#         model = tf.keras.models.load_model(os.path.join("files", "model.h5"))

    """ Dataset """
    test_x, test_y = X_test , y_test_mask1 

    """ Prediction and Evaluation """
    SCORE = []
    for i in tqdm(range(len(test_x))):
        x = test_x[i]
        y = test_y[i]

        """ Extracting the name """
        name = str(i)

        """ Reading the image """
        image = x       ## [H, w, 3]
        image = cv2.resize(image, (W, H))       ## [H, w, 3]
        x = image                         ## [H, w, 3]

        """ Reading the mask """
        mask = y        ## [H, w]
        mask = cv2.resize(mask, (W, H))         ## [H, w]
        y = mask                     ## [H, w]

        """ Prediction """
        y_pred = model_mask1_total.predict(np.expand_dims(x, axis=0))[0]
        y_pred = np.squeeze(y_pred)
        y_pred = (y_pred > 0.47).astype(np.uint8)

        """ Saving the results """
        save_image_path = os.path.join("results", f"{name}.png")
        save_results(image, mask, y_pred, save_image_path)
        
        """ Plotting the images """
        fig, axs = plt.subplots(1, 3, figsize=(10, 10))
        axs[0].imshow(image)
        axs[0].set_title('Image')
        axs[1].imshow(mask, cmap='gray')
        axs[1].set_title('Mask')
        axs[2].imshow(y_pred, cmap='gray')
        axs[2].set_title('Predicted Mask')
        plt.show()

#         """ Calculate the scores """
#         f1_value = f1_score(mask, y_pred, labels=[0, 1], average="binary")
#         jac_value = jaccard_score(mask, y_pred, labels=[0, 1], average="binary")
#         recall_value = recall_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
#         precision_value = precision_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
#         SCORE.append([name, f1_value, jac_value, recall_value, precision_value])
        
#     """ Metrics values """
#     score = [s[1:]for s in SCORE]
#     score = np.mean(score, axis=0)
#     print(f"F1: {score[0]:0.5f}")
#     print(f"Jaccard: {score[1]:0.5f}")
#     print(f"Recall: {score[2]:0.5f}")
#     print(f"Precision: {score[3]:0.5f}")

#     df = pd.DataFrame(SCORE, columns=["Image", "F1", "Jaccard", "Recall", "Precision"])
#     df.to_csv("files/score.csv")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 814ms/step
#  33%|███▎      | 1/3 [00:01<00:03,  1.51s/it]
# 1/1 [==============================] - 0s 173ms/step
#  67%|██████▋   | 2/3 [00:03<00:01,  1.60s/it]
# 1/1 [==============================] - 0s 185ms/step
# 100%|██████████| 3/3 [00:03<00:00,  1.25s/it]

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam


""" Global parameters """
H = 224
W = 224


def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)



def tf_parse(x, y):
    def _parse(x, y):
        x = cv2.resize(x, (W, H))
        x = x 
        x = x.astype(np.float32)
        y = cv2.resize(y, (W, H))
        y = y 
        y = y.astype(np.float32)
        y = np.expand_dims(y, axis=-1)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y


def tf_dataset(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 4
    lr = 1e-4
    num_epochs = 5
    model_path = os.path.join("files", "model.h5")
    csv_path = os.path.join("files", "log.csv")

    """ Dataset """
    train_x, train_y = X_train_total , y_train_mask2_total 
    test_x, test_y = X_test , y_test_mask2 

    print(f"Train: {len(X_train)} - {len(y_train_mask2_total)}")
    print(f"Test : {len(X_test)} - {len(y_test_mask2)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    test_dataset = tf_dataset(train_x, train_y, batch=batch_size)

    """ Model """
    model_mask2_total = build_unet2((H, W, 3)) #  Choose your model
    model_mask2_total.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef])

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False),
    ]

    model_mask2_total.fit(
        train_dataset,
        epochs=num_epochs,
        callbacks=callbacks
    )
# Out:
# Train: 12 - 659
# Test : 3 - 3
# Epoch 1/5
# 165/165 [==============================] - ETA: 0s - loss: -0.5434 - dice_coef: 1.5437WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 328s 2s/step - loss: -0.5434 - dice_coef: 1.5437 - lr: 1.0000e-04
# Epoch 2/5
# 165/165 [==============================] - ETA: 0s - loss: -0.8019 - dice_coef: 1.8020WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 310s 2s/step - loss: -0.8019 - dice_coef: 1.8020 - lr: 1.0000e-04
# Epoch 3/5
# 165/165 [==============================] - ETA: 0s - loss: -0.8417 - dice_coef: 1.8417WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 321s 2s/step - loss: -0.8417 - dice_coef: 1.8417 - lr: 1.0000e-04
# Epoch 4/5
# 165/165 [==============================] - ETA: 0s - loss: -0.8624 - dice_coef: 1.8625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 316s 2s/step - loss: -0.8624 - dice_coef: 1.8625 - lr: 1.0000e-04
# Epoch 5/5
# 165/165 [==============================] - ETA: 0s - loss: -0.8800 - dice_coef: 1.8801WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 320s 2s/step - loss: -0.8800 - dice_coef: 1.8801 - lr: 1.0000e-04

# %% [markdown]
# # UNet model trained on the breast cancer data :  MASK 2

# %%
# batch = 4 , 10 - 0.47 - 1e-4 mask 1 (Unet1)

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import f1_score, jaccard_score, precision_score, recall_score
from sklearn.model_selection import train_test_split


""" Global parameters """
H = 224
W = 224

""" Creating a directory """
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred * 255

    line = np.ones((H, 10, 3)) * 255

    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)
    return cat_images


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("results")

    """ Load the model """
#     with CustomObjectScope({"dice_coef": dice_coef, "dice_loss": dice_loss}):
#         model = tf.keras.models.load_model(os.path.join("files", "model.h5"))

    """ Dataset """
    test_x, test_y = X_test , y_test_mask2 

    """ Prediction and Evaluation """
    SCORE = []
    for i in tqdm(range(len(test_x))):
        x = test_x[i]
        y = test_y[i]

        """ Extracting the name """
        name = str(i)

        """ Reading the image """
        image = x       ## [H, w, 3]
        image = cv2.resize(image, (W, H))       ## [H, w, 3]
        x = image                         ## [H, w, 3]

        """ Reading the mask """
        mask = y        ## [H, w]
        mask = cv2.resize(mask, (W, H))         ## [H, w]
        y = mask                     ## [H, w]

        """ Prediction """
        y_pred = model_mask2_total.predict(np.expand_dims(x, axis=0))[0]
        y_pred = np.squeeze(y_pred)
        y_pred = (y_pred > 0.47).astype(np.uint8)

        """ Saving the results """
        save_image_path = os.path.join("results", f"{name}.png")
        save_results(image, mask, y_pred, save_image_path)
        
        """ Plotting the images """
        fig, axs = plt.subplots(1, 3, figsize=(10, 10))
        axs[0].imshow(image)
        axs[0].set_title('Image')
        axs[1].imshow(mask, cmap='gray')
        axs[1].set_title('Mask')
        axs[2].imshow(y_pred, cmap='gray')
        axs[2].set_title('Predicted Mask')
        plt.show()

#         """ Calculate the scores """
#         f1_value = f1_score(mask, y_pred, labels=[0, 1], average="binary")
#         jac_value = jaccard_score(mask, y_pred, labels=[0, 1], average="binary")
#         recall_value = recall_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
#         precision_value = precision_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
#         SCORE.append([name, f1_value, jac_value, recall_value, precision_value])
        
#     """ Metrics values """
#     score = [s[1:]for s in SCORE]
#     score = np.mean(score, axis=0)
#     print(f"F1: {score[0]:0.5f}")
#     print(f"Jaccard: {score[1]:0.5f}")
#     print(f"Recall: {score[2]:0.5f}")
#     print(f"Precision: {score[3]:0.5f}")

#     df = pd.DataFrame(SCORE, columns=["Image", "F1", "Jaccard", "Recall", "Precision"])
#     df.to_csv("files/score.csv")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 765ms/step
#  33%|███▎      | 1/3 [00:01<00:02,  1.22s/it]
# 1/1 [==============================] - 0s 185ms/step
#  67%|██████▋   | 2/3 [00:01<00:00,  1.15it/s]
# 1/1 [==============================] - 0s 190ms/step
# 100%|██████████| 3/3 [00:02<00:00,  1.23it/s]

# %% [markdown]
# # UNet model trained on the breast cancer data :  MASK 3

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam


""" Global parameters """
H = 224
W = 224


def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)



def tf_parse(x, y):
    def _parse(x, y):
        x = cv2.resize(x, (W, H))
        x = x 
        x = x.astype(np.float32)
        y = cv2.resize(y, (W, H))
        y = y 
        y = y.astype(np.float32)
        y = np.expand_dims(y, axis=-1)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y


def tf_dataset(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 4
    lr = 1e-4
    num_epochs = 5
    model_path = os.path.join("files", "model.h5")
    csv_path = os.path.join("files", "log.csv")

    """ Dataset """
    train_x, train_y = X_train_total , y_train_mask3_total 
    test_x, test_y = X_test , y_test_mask3 

    print(f"Train: {len(X_train)} - {len(y_train_mask3_total)}")
    print(f"Test : {len(X_test)} - {len(y_test_mask3)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    test_dataset = tf_dataset(train_x, train_y, batch=batch_size)

    """ Model """
    model_mask3_total = build_unet2((H, W, 3)) #  Choose your model
    model_mask3_total.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef])

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False),
    ]

    model_mask3_total.fit(
        train_dataset,
        epochs=num_epochs,
        callbacks=callbacks
    )
# Out:
# Train: 12 - 659
# Test : 3 - 3
# Epoch 1/5
# 165/165 [==============================] - ETA: 0s - loss: -0.6877 - dice_coef: 1.6880WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 302s 2s/step - loss: -0.6877 - dice_coef: 1.6880 - lr: 1.0000e-04
# Epoch 2/5
# 165/165 [==============================] - ETA: 0s - loss: -0.8470 - dice_coef: 1.8470WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 267s 2s/step - loss: -0.8470 - dice_coef: 1.8470 - lr: 1.0000e-04
# Epoch 3/5
# 165/165 [==============================] - ETA: 0s - loss: -0.8730 - dice_coef: 1.8730WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 248s 2s/step - loss: -0.8730 - dice_coef: 1.8730 - lr: 1.0000e-04
# Epoch 4/5
# 165/165 [==============================] - ETA: 0s - loss: -0.8841 - dice_coef: 1.8841WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 235s 1s/step - loss: -0.8841 - dice_coef: 1.8841 - lr: 1.0000e-04
# Epoch 5/5
# 165/165 [==============================] - ETA: 0s - loss: -0.8827 - dice_coef: 1.8828WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,dice_coef,lr
# 165/165 [==============================] - 237s 1s/step - loss: -0.8827 - dice_coef: 1.8828 - lr: 1.0000e-04

# %%
# batch = 4 , 10 - 0.47 - 1e-4 mask 1 (Unet1)

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import f1_score, jaccard_score, precision_score, recall_score
from sklearn.model_selection import train_test_split


""" Global parameters """
H = 224
W = 224

""" Creating a directory """
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred * 255

    line = np.ones((H, 10, 3)) * 255

    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)
    return cat_images


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("results")

    """ Load the model """
#     with CustomObjectScope({"dice_coef": dice_coef, "dice_loss": dice_loss}):
#         model = tf.keras.models.load_model(os.path.join("files", "model.h5"))

    """ Dataset """
    test_x, test_y = X_test , y_test_mask3 

    """ Prediction and Evaluation """
    SCORE = []
    for i in tqdm(range(len(test_x))):
        x = test_x[i]
        y = test_y[i]

        """ Extracting the name """
        name = str(i)

        """ Reading the image """
        image = x       ## [H, w, 3]
        image = cv2.resize(image, (W, H))       ## [H, w, 3]
        x = image                         ## [H, w, 3]

        """ Reading the mask """
        mask = y        ## [H, w]
        mask = cv2.resize(mask, (W, H))         ## [H, w]
        y = mask                     ## [H, w]

        """ Prediction """
        y_pred = model_mask3_total.predict(np.expand_dims(x, axis=0))[0]
        y_pred = np.squeeze(y_pred)
        y_pred = (y_pred > 0.47).astype(np.uint8)

        """ Saving the results """
        save_image_path = os.path.join("results", f"{name}.png")
        save_results(image, mask, y_pred, save_image_path)
        
        """ Plotting the images """
        fig, axs = plt.subplots(1, 3, figsize=(10, 10))
        axs[0].imshow(image)
        axs[0].set_title('Image')
        axs[1].imshow(mask, cmap='gray')
        axs[1].set_title('Mask')
        axs[2].imshow(y_pred, cmap='gray')
        axs[2].set_title('Predicted Mask')
        plt.show()

#         """ Calculate the scores """
#         f1_value = f1_score(mask, y_pred, labels=[0, 1], average="binary")
#         jac_value = jaccard_score(mask, y_pred, labels=[0, 1], average="binary")
#         recall_value = recall_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
#         precision_value = precision_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
#         SCORE.append([name, f1_value, jac_value, recall_value, precision_value])
        
#     """ Metrics values """
#     score = [s[1:]for s in SCORE]
#     score = np.mean(score, axis=0)
#     print(f"F1: {score[0]:0.5f}")
#     print(f"Jaccard: {score[1]:0.5f}")
#     print(f"Recall: {score[2]:0.5f}")
#     print(f"Precision: {score[3]:0.5f}")

#     df = pd.DataFrame(SCORE, columns=["Image", "F1", "Jaccard", "Recall", "Precision"])
#     df.to_csv("files/score.csv")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 431ms/step
#  33%|███▎      | 1/3 [00:00<00:01,  1.45it/s]
# 1/1 [==============================] - 0s 118ms/step
#  67%|██████▋   | 2/3 [00:01<00:00,  2.02it/s]
# 1/1 [==============================] - 0s 117ms/step
# 100%|██████████| 3/3 [00:01<00:00,  2.13it/s]

# %% [markdown]
# # Training the last layers (decoder) on the nerf optic data : MASK 1

# %%
from tensorflow.keras.models import Model

""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory for storing files """
create_dir("files")

""" Hyperparameters """
batch_size = 4
lr = 1e-4
num_epochs = 10
model_path = os.path.join("files", "model.h5")
csv_path = os.path.join("files", "log.csv")

""" Dataset """
train_x, train_y = X_train , mask1_dataset_train_
test_x, test_y = X_test , mask1_dataset_test



train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
test_dataset = tf_dataset(train_x, train_y, batch=batch_size)

""" Model """
weights = model_mask1_total.get_weights()
new_model_mask1 = build_unet2((H, W, 3))
new_model_mask1.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef])
new_model_mask1.set_weights(weights)

callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False),
    ]




# Assuming 'model' is your UNET model
encoder_decoder_mask1 = Model(inputs=new_model_mask1.input, outputs=new_model_mask1.output)

for layer in encoder_decoder_mask1.layers[:45]:
    layer.trainable = False



# # Create the decoder part of the model
# decoder_input = Input(shape=encoder.output.shape[1:])  # Use encoder output shape as input shape
# decoder_output = new_model(decoder_input)  # Pass the input through the new_model
# decoder = Model(inputs=decoder_input, outputs=decoder_output)

# Compile the decoder with desired optimizer and loss function
encoder_decoder_mask1.compile(optimizer='adam', loss='binary_crossentropy')

# # Train the decoder with your data
# encoder_decoder_mask1.fit(train_dataset,
#             epochs=num_epochs*16,
#             callbacks=callbacks)


epoch_loss_values = []  # List to store the loss of each epoch

# ... previous code ...

for epoch in range(num_epochs*16):
    # Train the decoder with your data
    history = encoder_decoder_mask1.fit(train_dataset, epochs=1, callbacks=callbacks)
    
    # Access the loss value for the current epoch from the training history
    epoch_loss = history.history['loss'][0]
    epoch_loss_values.append(epoch_loss)

X = [i+1 for i in range(num_epochs*16)]

plt.plot(X, epoch_loss_values)
# Out:
# 3/3 [==============================] - ETA: 0s - loss: -237.6723WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 6s 870ms/step - loss: -237.6723 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -291.1953WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 829ms/step - loss: -291.1953 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -319.2843WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 858ms/step - loss: -319.2843 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -346.5851WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 851ms/step - loss: -346.5851 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -363.4309WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 852ms/step - loss: -363.4309 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -390.1069WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 869ms/step - loss: -390.1069 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -405.5753WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 816ms/step - loss: -405.5753 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -421.5125WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 819ms/step - loss: -421.5125 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -438.2232WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 819ms/step - loss: -438.2232 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -457.1845WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 846ms/step - loss: -457.1845 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -473.2025WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 817ms/step - loss: -473.2025 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -492.4316WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 823ms/step - loss: -492.4316 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -496.9368WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 829ms/step - loss: -496.9368 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -506.4863WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 826ms/step - loss: -506.4863 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -524.2053WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 827ms/step - loss: -524.2053 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -519.6954WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 819ms/step - loss: -519.6954 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -545.5963WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 849ms/step - loss: -545.5963 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -566.5504WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 841ms/step - loss: -566.5504 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -579.5494WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 862ms/step - loss: -579.5494 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -605.6164WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 833ms/step - loss: -605.6164 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -614.5898WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 837ms/step - loss: -614.5898 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -630.1545WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 870ms/step - loss: -630.1545 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -632.1945WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 834ms/step - loss: -632.1945 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -640.5386WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 847ms/step - loss: -640.5386 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -651.8945WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 863ms/step - loss: -651.8945 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -675.0624WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 832ms/step - loss: -675.0624 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -685.5900WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 849ms/step - loss: -685.5900 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -710.3398WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 861ms/step - loss: -710.3398 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -723.7574WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 876ms/step - loss: -723.7574 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -739.1330WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 864ms/step - loss: -739.1330 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -750.3632WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 848ms/step - loss: -750.3632 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -769.3804WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 870ms/step - loss: -769.3804 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -782.5245WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 835ms/step - loss: -782.5245 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -801.5977WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 841ms/step - loss: -801.5977 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -808.0557WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 835ms/step - loss: -808.0557 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -827.6979WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 831ms/step - loss: -827.6979 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -841.5825WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 832ms/step - loss: -841.5825 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -863.2767WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 821ms/step - loss: -863.2767 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -875.7551WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 815ms/step - loss: -875.7551 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -885.3063WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 942ms/step - loss: -885.3063 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -897.1872WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 925ms/step - loss: -897.1872 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -904.9628WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 955ms/step - loss: -904.9628 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -920.8303WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 962ms/step - loss: -920.8303 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -939.5891WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 977ms/step - loss: -939.5891 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -951.4816WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 918ms/step - loss: -951.4816 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -972.5435WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 915ms/step - loss: -972.5435 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -989.0745WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 901ms/step - loss: -989.0745 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -997.9600WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 904ms/step - loss: -997.9600 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1026.7587WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 907ms/step - loss: -1026.7587 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1039.6200WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 902ms/step - loss: -1039.6200 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1051.5260WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 924ms/step - loss: -1051.5260 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1066.4155WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 892ms/step - loss: -1066.4155 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1087.7218WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 899ms/step - loss: -1087.7218 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1094.4596WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 895ms/step - loss: -1094.4596 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1110.8153WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 899ms/step - loss: -1110.8153 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1109.4423WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 914ms/step - loss: -1109.4423 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1129.3818WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 891ms/step - loss: -1129.3818 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1150.9203WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 898ms/step - loss: -1150.9203 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1164.0990WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 892ms/step - loss: -1164.0990 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1183.0900WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 886ms/step - loss: -1183.0900 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1190.3992WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 907ms/step - loss: -1190.3992 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1204.0248WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 938ms/step - loss: -1204.0248 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1229.0477WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 911ms/step - loss: -1229.0477 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1247.3374WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 894ms/step - loss: -1247.3374 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1251.8153WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 908ms/step - loss: -1251.8153 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1276.0371WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 892ms/step - loss: -1276.0371 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1299.3546WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 896ms/step - loss: -1299.3546 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1313.7020WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 913ms/step - loss: -1313.7020 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1322.4501WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 921ms/step - loss: -1322.4501 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1345.8798WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 910ms/step - loss: -1345.8798 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1364.4624WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 890ms/step - loss: -1364.4624 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1384.7705WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 883ms/step - loss: -1384.7705 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1406.3959WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 900ms/step - loss: -1406.3959 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1425.2578WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 889ms/step - loss: -1425.2578 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1443.6371WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 895ms/step - loss: -1443.6371 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1460.7162WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 889ms/step - loss: -1460.7162 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1475.2174WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 878ms/step - loss: -1475.2174 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1490.6761WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 852ms/step - loss: -1490.6761 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1499.9398WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 858ms/step - loss: -1499.9398 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1519.0699WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 849ms/step - loss: -1519.0699 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1530.9086WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 875ms/step - loss: -1530.9086 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1548.8219WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 853ms/step - loss: -1548.8219 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1567.0219WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 862ms/step - loss: -1567.0219 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1592.7946WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 862ms/step - loss: -1592.7946 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1605.0934WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 852ms/step - loss: -1605.0934 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1619.7177WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 863ms/step - loss: -1619.7177 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1634.4508WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 852ms/step - loss: -1634.4508 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1655.4535WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 859ms/step - loss: -1655.4535 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1673.5262WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 847ms/step - loss: -1673.5262 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1698.7667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 859ms/step - loss: -1698.7667 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1719.3658WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 873ms/step - loss: -1719.3658 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1738.8046WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 866ms/step - loss: -1738.8046 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1755.9760WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 871ms/step - loss: -1755.9760 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1778.2579WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 857ms/step - loss: -1778.2579 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1797.1456WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 891ms/step - loss: -1797.1456 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1815.9043WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 884ms/step - loss: -1815.9043 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1834.1823WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 865ms/step - loss: -1834.1823 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1852.2562WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 879ms/step - loss: -1852.2562 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1873.0765WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 849ms/step - loss: -1873.0765 - lr: 0.0010
# ...
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 860ms/step - loss: -2467.9902 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2489.7898WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 875ms/step - loss: -2489.7898 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2510.2266WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 884ms/step - loss: -2510.2266 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2529.9851WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 869ms/step - loss: -2529.9851 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2550.3564WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 865ms/step - loss: -2550.3564 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2568.3184WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 863ms/step - loss: -2568.3184 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2588.7175WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 860ms/step - loss: -2588.7175 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2607.3333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 854ms/step - loss: -2607.3333 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2624.6875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 846ms/step - loss: -2624.6875 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2643.0300WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 850ms/step - loss: -2643.0300 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2663.3713WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 840ms/step - loss: -2663.3713 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2689.5859WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 849ms/step - loss: -2689.5859 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2710.9392WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 830ms/step - loss: -2710.9392 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2730.4343WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 857ms/step - loss: -2730.4343 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2740.5789WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 871ms/step - loss: -2740.5789 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2760.4041WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 837ms/step - loss: -2760.4041 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2761.2019WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 928ms/step - loss: -2761.2019 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2783.0447WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 858ms/step - loss: -2783.0447 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2780.6165WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 889ms/step - loss: -2780.6165 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2805.2537WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 853ms/step - loss: -2805.2537 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2707.6877WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 881ms/step - loss: -2707.6877 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2777.7195WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 830ms/step - loss: -2777.7195 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2778.2708WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 840ms/step - loss: -2778.2708 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2794.5784WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 844ms/step - loss: -2794.5784 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2834.8027WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 831ms/step - loss: -2834.8027 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2875.0520WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 832ms/step - loss: -2875.0520 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2940.7090WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 852ms/step - loss: -2940.7090 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2989.4338WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 839ms/step - loss: -2989.4338 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3023.6182WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 836ms/step - loss: -3023.6182 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3067.9050WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 847ms/step - loss: -3067.9050 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3107.7844WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 864ms/step - loss: -3107.7844 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3139.2849WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 840ms/step - loss: -3139.2849 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3173.5793WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 841ms/step - loss: -3173.5793 - lr: 0.0010

# %%
X = [i+1 for i in range((16*num_epochs))]
plt.plot(X, epoch_loss_values)
plt.legend("Loss")
plt.title("Loss evolution : binary crossentropy")
plt.show()

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import f1_score, jaccard_score, precision_score, recall_score
from sklearn.model_selection import train_test_split


""" Global parameters """
H = 224
W = 224

""" Creating a directory """
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred * 255

    line = np.ones((H, 10, 3)) * 255

    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)
    return cat_images


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("results")

    """ Load the model """
#     with CustomObjectScope({"dice_coef": dice_coef, "dice_loss": dice_loss}):
#         model = tf.keras.models.load_model(os.path.join("files", "model.h5"))

    """ Dataset """

    test_x, test_y = X_test , y_test_mask1 

    """ Prediction and Evaluation """
    SCORE = []
    for i in tqdm(range(len(test_x))):
        x = test_x[i]
        y = test_y[i]

        """ Extracting the name """
        name = str(i)

        """ Reading the image """
        image = x       ## [H, w, 3]
        image = cv2.resize(image, (W, H))       ## [H, w, 3]
        x = image                         ## [H, w, 3]

        """ Reading the mask """
        mask = y        ## [H, w]
        mask = cv2.resize(mask, (W, H))         ## [H, w]
        y = mask                     ## [H, w]

        """ Prediction """
        y_pred = encoder_decoder_mask1.predict(np.expand_dims(x, axis=0))[0]
        y_pred = np.squeeze(y_pred)
        y_pred = (y_pred > 0.9).astype(np.uint8)

        """ Saving the results """
        save_image_path = os.path.join("results", f"{name}.png")
        save_results(image, mask, y_pred, save_image_path)
        

        """metrics"""

        df = calculate_segmentation_metrics(mask, y_pred)
        display(df)


        """ Plotting the images """
        fig, axs = plt.subplots(1, 3, figsize=(10, 10))
        axs[0].imshow(image)
        axs[0].set_title('Image')
        axs[1].imshow(mask, cmap='gray')
        axs[1].set_title('Mask')
        axs[2].imshow(y_pred, cmap='gray')
        axs[2].set_title('Predicted Mask')
        plt.show()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 420ms/step
#             Metrics     Score
# 0               IoU  0.508514
# 1  Dice Coefficient  0.005693
# 2    Pixel Accuracy  0.569296
#  33%|███▎      | 1/3 [00:00<00:01,  1.43it/s]
# 1/1 [==============================] - 0s 110ms/step
#             Metrics     Score
# 0               IoU  0.471404
# 1  Dice Coefficient  0.005432
# 2    Pixel Accuracy  0.545719
#  67%|██████▋   | 2/3 [00:01<00:00,  2.02it/s]
# 1/1 [==============================] - 0s 110ms/step
#             Metrics     Score
# 0               IoU  0.621338
# 1  Dice Coefficient  0.006349
# 2    Pixel Accuracy  0.642837
# 100%|██████████| 3/3 [00:01<00:00,  2.13it/s]

# %% [markdown]
# # Training the last layers (decoder) on the nerf optic data : MASK 2

# %%
from tensorflow.keras.models import Model

""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory for storing files """
create_dir("files")

""" Hyperparameters """
batch_size = 4
lr = 1e-4
num_epochs = 10
model_path = os.path.join("files", "model.h5")
csv_path = os.path.join("files", "log.csv")

""" Dataset """
train_x, train_y = X_train , mask2_dataset_train_
test_x, test_y = X_test , mask2_dataset_test



train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
test_dataset = tf_dataset(train_x, train_y, batch=batch_size)

""" Model """
weights = model_mask2_total.get_weights()
new_model_mask2 = build_unet2((H, W, 3))
new_model_mask2.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef])
new_model_mask2.set_weights(weights)

callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False),
    ]




# Assuming 'model' is your UNET model
encoder_decoder_mask2 = Model(inputs=new_model_mask2.input, outputs=new_model_mask2.output)

for layer in encoder_decoder_mask2.layers[:45]:
    layer.trainable = False



# # Create the decoder part of the model
# decoder_input = Input(shape=encoder.output.shape[1:])  # Use encoder output shape as input shape
# decoder_output = new_model(decoder_input)  # Pass the input through the new_model
# decoder = Model(inputs=decoder_input, outputs=decoder_output)

# Compile the decoder with desired optimizer and loss function
encoder_decoder_mask2.compile(optimizer='adam', loss='binary_crossentropy')

# # Train the decoder with your data
# encoder_decoder_mask2.fit(train_dataset,
#             epochs=num_epochs*16,
#             callbacks=callbacks)


epoch_loss_values2 = []  # List to store the loss of each epoch

# ... previous code ...

for epoch in range(num_epochs*25):
    # Train the decoder with your data
    history = encoder_decoder_mask2.fit(train_dataset, epochs=1, callbacks=callbacks)
    
    # Access the loss value for the current epoch from the training history
    epoch_loss = history.history['loss'][0]
    epoch_loss_values2.append(epoch_loss)

X = [i+1 for i in range(num_epochs*25)]

plt.plot(X, epoch_loss_values2)
plt.legend("Loss")
plt.title("Loss evolution : binary crossentropy")
plt.show()
# Out:
# 3/3 [==============================] - ETA: 0s - loss: -85.1879WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 7s 1s/step - loss: -85.1879 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -145.7725WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 967ms/step - loss: -145.7725 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -162.7343WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 913ms/step - loss: -162.7343 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -179.8599WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 954ms/step - loss: -179.8599 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -190.5765WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 945ms/step - loss: -190.5765 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -205.4751WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 901ms/step - loss: -205.4751 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -215.7199WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 908ms/step - loss: -215.7199 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -230.1767WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 905ms/step - loss: -230.1767 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -246.9729WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 938ms/step - loss: -246.9729 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -256.5286WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 933ms/step - loss: -256.5286 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -265.4752WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 945ms/step - loss: -265.4752 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -276.9571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 961ms/step - loss: -276.9571 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -288.8342WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 962ms/step - loss: -288.8342 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -298.8748WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 924ms/step - loss: -298.8748 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -312.8941WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 948ms/step - loss: -312.8941 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -326.3557WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 962ms/step - loss: -326.3557 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -331.4734WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 983ms/step - loss: -331.4734 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -346.9321WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 984ms/step - loss: -346.9321 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -357.1628WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 997ms/step - loss: -357.1628 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -370.7934WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -370.7934 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -379.2837WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -379.2837 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -381.0656WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -381.0656 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -383.0845WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -383.0845 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -395.2760WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -395.2760 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -410.9060WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 999ms/step - loss: -410.9060 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -420.9704WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -420.9704 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -425.9467WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -425.9467 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -437.1471WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -437.1471 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -453.8936WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -453.8936 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -462.5404WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -462.5404 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -475.0261WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -475.0261 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -481.1942WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -481.1942 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -494.5413WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -494.5413 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -505.2461WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -505.2461 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -517.5717WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -517.5717 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -526.9106WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -526.9106 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -532.3625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -532.3625 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -541.7477WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -541.7477 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -556.2791WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -556.2791 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -567.1379WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -567.1379 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -576.3469WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -576.3469 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -585.0369WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -585.0369 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -591.8029WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -591.8029 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -602.3605WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -602.3605 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -609.9661WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1000ms/step - loss: -609.9661 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -620.0298WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -620.0298 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -632.0576WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -632.0576 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -640.4771WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -640.4771 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -649.9059WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -649.9059 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -660.8361WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -660.8361 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -669.7801WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -669.7801 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -679.0529WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -679.0529 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -687.2393WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -687.2393 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -695.9664WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 995ms/step - loss: -695.9664 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -706.7857WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -706.7857 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -718.1072WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -718.1072 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -725.6462WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1000ms/step - loss: -725.6462 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -733.4404WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -733.4404 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -744.2393WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -744.2393 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -753.3359WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -753.3359 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -754.6794WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -754.6794 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -763.6541WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -763.6541 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -767.0183WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -767.0183 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -776.6812WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -776.6812 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -788.2864WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -788.2864 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -795.4775WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -795.4775 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -812.2462WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -812.2462 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -822.1605WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -822.1605 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -830.8336WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -830.8336 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -838.9138WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -838.9138 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -850.4797WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -850.4797 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -862.7402WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -862.7402 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -874.6917WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -874.6917 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -887.2934WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -887.2934 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -899.7896WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -899.7896 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -912.2007WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -912.2007 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -923.8141WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -923.8141 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -934.1768WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -934.1768 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -945.4462WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -945.4462 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -956.2475WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -956.2475 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -966.3118WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -966.3118 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -975.5781WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -975.5781 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -986.2144WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -986.2144 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -996.2453WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -996.2453 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1006.2062WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1006.2062 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1015.4114WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1015.4114 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1025.5153WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1025.5153 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1038.0582WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1038.0582 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1051.5404WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1051.5404 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1063.3221WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1063.3221 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1073.9144WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1073.9144 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1084.1234WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1084.1234 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1093.6418WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1093.6418 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1101.5172WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1101.5172 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1112.1348WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1112.1348 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1120.7479WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1120.7479 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1122.6647WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1122.6647 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1133.6837WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1133.6837 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1136.5616WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -1136.5616 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1144.6270WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# ...
# 3/3 [==============================] - ETA: 0s - loss: -2973.9656WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2973.9656 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2992.8867WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2992.8867 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3012.5420WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -3012.5420 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3031.4285WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -3031.4285 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3050.7900WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 935ms/step - loss: -3050.7900 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3070.5598WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 896ms/step - loss: -3070.5598 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3088.4617WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 983ms/step - loss: -3088.4617 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3106.2288WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 953ms/step - loss: -3106.2288 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3126.1426WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 941ms/step - loss: -3126.1426 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3144.9265WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 954ms/step - loss: -3144.9265 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3163.7703WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 941ms/step - loss: -3163.7703 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3182.9480WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 937ms/step - loss: -3182.9480 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3201.3311WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 954ms/step - loss: -3201.3311 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3219.0872WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 965ms/step - loss: -3219.0872 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3237.1956WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 948ms/step - loss: -3237.1956 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3257.7588WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 925ms/step - loss: -3257.7588 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3278.8782WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 939ms/step - loss: -3278.8782 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3298.8250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 940ms/step - loss: -3298.8250 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3317.8005WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 915ms/step - loss: -3317.8005 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3337.5107WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 965ms/step - loss: -3337.5107 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3355.3479WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 982ms/step - loss: -3355.3479 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3371.2878WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 987ms/step - loss: -3371.2878 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3381.8269WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -3381.8269 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3388.3513WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -3388.3513 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3319.2683WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -3319.2683 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2861.2588WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -2861.2588 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2661.4119WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -2661.4119 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2620.6799WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -2620.6799 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2869.3582WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -2869.3582 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2889.8796WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -2889.8796 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3034.4734WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -3034.4734 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3067.2336WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -3067.2336 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3218.2302WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -3218.2302 - lr: 0.0010

# %%
plt.plot(X, epoch_loss_values2)
plt.legend("Loss")
plt.title("Loss evolution : binary crossentropy")
plt.show()

# %%
X = [i+1 for i in range((16*num_epochs))]
plt.plot(X, epoch_loss_values3)
plt.legend("Loss")
plt.title("Loss evolution : binary crossentropy")
plt.show()

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import f1_score, jaccard_score, precision_score, recall_score
from sklearn.model_selection import train_test_split


""" Global parameters """
H = 224
W = 224

""" Creating a directory """
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred * 255

    line = np.ones((H, 10, 3)) * 255

    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)
    return cat_images


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("results")

    """ Load the model """
#     with CustomObjectScope({"dice_coef": dice_coef, "dice_loss": dice_loss}):
#         model = tf.keras.models.load_model(os.path.join("files", "model.h5"))

    """ Dataset """

    test_x, test_y = X_test , y_test_mask2 

    """ Prediction and Evaluation """
    SCORE = []
    for i in tqdm(range(len(test_x))):
        x = test_x[i]
        y = test_y[i]

        """ Extracting the name """
        name = str(i)

        """ Reading the image """
        image = x       ## [H, w, 3]
        image = cv2.resize(image, (W, H))       ## [H, w, 3]
        x = image                         ## [H, w, 3]

        """ Reading the mask """
        mask = y        ## [H, w]
        mask = cv2.resize(mask, (W, H))         ## [H, w]
        y = mask                     ## [H, w]

        """ Prediction """
        y_pred = encoder_decoder_mask2.predict(np.expand_dims(x, axis=0))[0]
        y_pred = np.squeeze(y_pred)
        y_pred = (y_pred > 0.9).astype(np.uint8)

        """ Saving the results """
        save_image_path = os.path.join("results", f"{name}.png")
        save_results(image, mask, y_pred, save_image_path)
        
        """metrics"""

        df = calculate_segmentation_metrics(mask, y_pred)
        display(df)

        
        """ Plotting the images """
        fig, axs = plt.subplots(1, 3, figsize=(10, 10))
        axs[0].imshow(image)
        axs[0].set_title('Image')
        axs[1].imshow(mask, cmap='gray')
        axs[1].set_title('Mask')
        axs[2].imshow(y_pred, cmap='gray')
        axs[2].set_title('Predicted Mask')
        plt.show()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 1/1 [==============================] - 1s 895ms/step
#             Metrics     Score
# 0               IoU  0.309765
# 1  Dice Coefficient  0.107289
# 2    Pixel Accuracy  0.472178
#  33%|███▎      | 1/3 [00:01<00:02,  1.39s/it]
# 1/1 [==============================] - 0s 188ms/step
#             Metrics     Score
# 0               IoU  0.282730
# 1  Dice Coefficient  0.106907
# 2    Pixel Accuracy  0.487305
#  67%|██████▋   | 2/3 [00:01<00:00,  1.08it/s]
# 1/1 [==============================] - 0s 164ms/step
#             Metrics     Score
# 0               IoU  0.374152
# 1  Dice Coefficient  0.098075
# 2    Pixel Accuracy  0.616191
# 100%|██████████| 3/3 [00:04<00:00,  1.47s/it]

# %% [markdown]
# # Training the last layers (decoder) on the nerf optic data : MASK 3

# %%
from tensorflow.keras.models import Model

""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory for storing files """
create_dir("files")

""" Hyperparameters """
batch_size = 4
lr = 1e-4
num_epochs = 10
model_path = os.path.join("files", "model.h5")
csv_path = os.path.join("files", "log.csv")

""" Dataset """
train_x, train_y = X_train , mask3_dataset_train_
test_x, test_y = X_test , mask3_dataset_test



train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
test_dataset = tf_dataset(train_x, train_y, batch=batch_size)

""" Model """
weights = model_mask3_total.get_weights()
new_model_mask3 = build_unet2((H, W, 3))
new_model_mask3.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef])
new_model_mask3.set_weights(weights)

callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False),
    ]




# Assuming 'model' is your UNET model
encoder_decoder_mask3 = Model(inputs=new_model_mask3.input, outputs=new_model_mask3.output)

for layer in encoder_decoder_mask3.layers[:45]:
    layer.trainable = False



# # Create the decoder part of the model
# decoder_input = Input(shape=encoder.output.shape[1:])  # Use encoder output shape as input shape
# decoder_output = new_model(decoder_input)  # Pass the input through the new_model
# decoder = Model(inputs=decoder_input, outputs=decoder_output)

# Compile the decoder with desired optimizer and loss function
encoder_decoder_mask3.compile(optimizer='adam', loss='binary_crossentropy')

# Train the decoder with your data
# encoder_decoder_mask3.fit(train_dataset,
#             epochs=num_epochs*16,
#             callbacks=callbacks)

epoch_loss_values3 = []  # List to store the loss of each epoch

# ... previous code ...

for epoch in range(num_epochs*16):
    # Train the decoder with your data
    history = encoder_decoder_mask3.fit(train_dataset, epochs=1, callbacks=callbacks)
    
    # Access the loss value for the current epoch from the training history
    epoch_loss = history.history['loss'][0]
    epoch_loss_values3.append(epoch_loss)

X = [i+1 for i in range(num_epochs*16)]

plt.plot(X, epoch_loss_values3)
# Out:
# 3/3 [==============================] - ETA: 0s - loss: -155.4711WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 6s 893ms/step - loss: -155.4711 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -300.2688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 867ms/step - loss: -300.2688 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -337.8421WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 853ms/step - loss: -337.8421 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -380.8515WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 864ms/step - loss: -380.8515 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -428.2534WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 860ms/step - loss: -428.2534 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -480.1392WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 854ms/step - loss: -480.1392 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -535.9031WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 826ms/step - loss: -535.9031 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -575.4355WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 843ms/step - loss: -575.4355 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -609.1909WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 834ms/step - loss: -609.1909 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -637.5945WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 848ms/step - loss: -637.5945 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -663.5682WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 837ms/step - loss: -663.5682 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -699.0350WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 809ms/step - loss: -699.0350 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -722.5503WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 794ms/step - loss: -722.5503 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -742.6111WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 844ms/step - loss: -742.6111 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -757.6700WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 805ms/step - loss: -757.6700 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -771.6895WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 819ms/step - loss: -771.6895 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -808.9966WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 848ms/step - loss: -808.9966 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -831.6649WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 841ms/step - loss: -831.6649 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -851.9194WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 866ms/step - loss: -851.9194 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -875.6979WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 805ms/step - loss: -875.6979 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -894.8867WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 800ms/step - loss: -894.8867 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -914.1230WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 807ms/step - loss: -914.1230 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -929.7180WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 798ms/step - loss: -929.7180 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -955.1852WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 825ms/step - loss: -955.1852 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -974.8521WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 823ms/step - loss: -974.8521 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -998.5329WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 853ms/step - loss: -998.5329 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1015.9956WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 847ms/step - loss: -1015.9956 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1038.0192WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 817ms/step - loss: -1038.0192 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1060.4645WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 833ms/step - loss: -1060.4645 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1075.7269WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 798ms/step - loss: -1075.7269 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1094.8564WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 852ms/step - loss: -1094.8564 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1115.7212WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 868ms/step - loss: -1115.7212 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1132.7174WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 870ms/step - loss: -1132.7174 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1154.5551WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 860ms/step - loss: -1154.5551 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1165.2018WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 850ms/step - loss: -1165.2018 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1177.6812WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 848ms/step - loss: -1177.6812 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1194.0468WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 822ms/step - loss: -1194.0468 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1222.1855WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 839ms/step - loss: -1222.1855 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1245.0953WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 871ms/step - loss: -1245.0953 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1266.9374WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 870ms/step - loss: -1266.9374 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1284.4718WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 886ms/step - loss: -1284.4718 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1300.6014WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 865ms/step - loss: -1300.6014 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1320.8134WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 850ms/step - loss: -1320.8134 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1344.5753WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 808ms/step - loss: -1344.5753 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1364.0127WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 830ms/step - loss: -1364.0127 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1388.0765WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 810ms/step - loss: -1388.0765 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1396.5590WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 804ms/step - loss: -1396.5590 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1409.2212WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 817ms/step - loss: -1409.2212 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1439.9716WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 805ms/step - loss: -1439.9716 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1452.5352WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 814ms/step - loss: -1452.5352 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1482.3619WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 804ms/step - loss: -1482.3619 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1508.9424WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 809ms/step - loss: -1508.9424 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1530.1544WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 813ms/step - loss: -1530.1544 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1546.8516WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 814ms/step - loss: -1546.8516 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1563.6207WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 810ms/step - loss: -1563.6207 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1588.5753WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 845ms/step - loss: -1588.5753 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1610.0270WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 851ms/step - loss: -1610.0270 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1633.5563WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 860ms/step - loss: -1633.5563 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1643.5392WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 864ms/step - loss: -1643.5392 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1665.7614WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 885ms/step - loss: -1665.7614 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1682.0552WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 810ms/step - loss: -1682.0552 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1704.6735WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 807ms/step - loss: -1704.6735 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1713.9355WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 832ms/step - loss: -1713.9355 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1749.6826WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 816ms/step - loss: -1749.6826 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1781.3986WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 832ms/step - loss: -1781.3986 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1803.6998WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 838ms/step - loss: -1803.6998 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1837.0397WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 809ms/step - loss: -1837.0397 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1861.2412WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 815ms/step - loss: -1861.2412 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1886.2826WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 842ms/step - loss: -1886.2826 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1914.4711WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 899ms/step - loss: -1914.4711 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1938.7574WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 855ms/step - loss: -1938.7574 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1964.5200WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 857ms/step - loss: -1964.5200 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -1984.8456WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 2s 820ms/step - loss: -1984.8456 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2019.8898WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 853ms/step - loss: -2019.8898 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2047.8163WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 948ms/step - loss: -2047.8163 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2075.9729WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 956ms/step - loss: -2075.9729 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2102.3701WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 977ms/step - loss: -2102.3701 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2130.4133WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 962ms/step - loss: -2130.4133 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2155.9895WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 991ms/step - loss: -2155.9895 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2179.3381WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 969ms/step - loss: -2179.3381 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2202.9875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 967ms/step - loss: -2202.9875 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2227.9224WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 993ms/step - loss: -2227.9224 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2253.2502WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -2253.2502 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2284.8625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -2284.8625 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2314.0469WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2314.0469 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2346.9463WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2346.9463 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2376.6978WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2376.6978 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2406.8003WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2406.8003 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2435.8027WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2435.8027 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2464.3770WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2464.3770 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2487.7319WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2487.7319 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2516.2937WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -2516.2937 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2548.4775WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -2548.4775 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2577.3132WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2577.3132 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2607.8867WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -2607.8867 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2639.6970WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2639.6970 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2671.0310WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2671.0310 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2701.2444WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -2701.2444 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -2732.7266WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -2732.7266 - lr: 0.0010
# ...
# 3/3 [==============================] - 3s 1s/step - loss: -3582.8855 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3611.9421WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -3611.9421 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3667.0242WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -3667.0242 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3707.5208WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -3707.5208 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3753.3596WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -3753.3596 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3793.5703WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -3793.5703 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3832.5833WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -3832.5833 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3872.2048WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -3872.2048 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3912.7249WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -3912.7249 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3953.7793WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -3953.7793 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -3993.9023WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -3993.9023 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4034.6912WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4034.6912 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4071.6750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4071.6750 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4111.1777WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4111.1777 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4152.0190WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4152.0190 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4192.7559WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4192.7559 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4236.3433WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4236.3433 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4275.1636WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4275.1636 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4316.6860WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4316.6860 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4355.4336WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4355.4336 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4393.1509WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4393.1509 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4436.0034WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4436.0034 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4478.2202WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4478.2202 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4516.8237WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4516.8237 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4550.3770WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4550.3770 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4575.2349WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4575.2349 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4621.8237WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4621.8237 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4669.6851WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -4669.6851 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4714.1929WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -4714.1929 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4755.8774WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -4755.8774 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4801.1909WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -4801.1909 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4839.0132WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -4839.0132 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4877.8862WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 3s 1s/step - loss: -4877.8862 - lr: 0.0010
# 3/3 [==============================] - ETA: 0s - loss: -4921.2261WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 3/3 [==============================] - 4s 1s/step - loss: -4921.2261 - lr: 0.0010

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import f1_score, jaccard_score, precision_score, recall_score
from sklearn.model_selection import train_test_split


""" Global parameters """
H = 224
W = 224

""" Creating a directory """
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred * 255

    line = np.ones((H, 10, 3)) * 255

    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)
    return cat_images


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("results")

    """ Load the model """
#     with CustomObjectScope({"dice_coef": dice_coef, "dice_loss": dice_loss}):
#         model = tf.keras.models.load_model(os.path.join("files", "model.h5"))

    """ Dataset """

    test_x, test_y = X_test , y_test_mask3 

    """ Prediction and Evaluation """
    SCORE = []
    for i in tqdm(range(len(test_x))):
        x = test_x[i]
        y = test_y[i]

        """ Extracting the name """
        name = str(i)

        """ Reading the image """
        image = x       ## [H, w, 3]
        image = cv2.resize(image, (W, H))       ## [H, w, 3]
        x = image                         ## [H, w, 3]

        """ Reading the mask """
        mask = y        ## [H, w]
        mask = cv2.resize(mask, (W, H))         ## [H, w]
        y = mask                     ## [H, w]

        """ Prediction """
        y_pred = encoder_decoder_mask3.predict(np.expand_dims(x, axis=0))[0]
        y_pred = np.squeeze(y_pred)
        y_pred = (y_pred > 0.9).astype(np.uint8)

        """ Saving the results """
        save_image_path = os.path.join("results", f"{name}.png")
        save_results(image, mask, y_pred, save_image_path)
        

        """metrics"""

        df = calculate_segmentation_metrics(mask, y_pred)
        display(df)


        """ Plotting the images """
        fig, axs = plt.subplots(1, 3, figsize=(10, 10))
        axs[0].imshow(image)
        axs[0].set_title('Image')
        axs[1].imshow(mask, cmap='gray')
        axs[1].set_title('Mask')
        axs[2].imshow(y_pred, cmap='gray')
        axs[2].set_title('Predicted Mask')
        plt.show()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000016E6AC06700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 779ms/step
#             Metrics     Score
# 0               IoU  0.635470
# 1  Dice Coefficient  0.094464
# 2    Pixel Accuracy  0.335678
#  33%|███▎      | 1/3 [00:01<00:02,  1.21s/it]
# 1/1 [==============================] - 0s 184ms/step
#             Metrics     Score
# 0               IoU  0.708653
# 1  Dice Coefficient  0.097865
# 2    Pixel Accuracy  0.366191
#  67%|██████▋   | 2/3 [00:01<00:00,  1.19it/s]
# 1/1 [==============================] - 0s 172ms/step
#             Metrics     Score
# 0               IoU  0.542675
# 1  Dice Coefficient  0.075622
# 2    Pixel Accuracy  0.332290
# 100%|██████████| 3/3 [00:02<00:00,  1.26it/s]
